# %%
from curl_cffi import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.whoscored.com/matches/1903442/live/england-premier-league-2025-2026-bournemouth-manchester-city"

# %%
headers = {
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
            "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8",
            "accept-language": "en-US,en;q=0.9",
            "referer": "https://www.google.com/"
}
response = requests.get(url,headers = headers, impersonate = "chrome120", timeout = 30)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
element = soup.select_one('script:-soup-contains("matchCentreData")')

# %%
raw_text = element.text.split("matchCentreData: ")[1].strip()

# %%
import json
data, _ = json.JSONDecoder().raw_decode(raw_text)

# %%
data
# Out:
# {'playerIdNameDictionary': {'328330': 'Marcos Senesi',
#   '384430': 'Evanilson',
#   '479170': 'Junior Kroupi',
#   '398301': 'Adrien Truffert',
#   '366875': 'Bafodé Diakité',
#   '418171': 'Christos Mandas',
#   '476166': 'Alex Tóth',
#   '389409': 'Amine Adli',
#   '331579': 'Justin Kluivert',
#   '406564': 'Djordje Petrovic',
#   '134695': 'Enes Ünal',
#   '315275': 'Tyler Adams',
#   '69877': 'Adam Smith',
#   '136456': 'Lewis Cook',
#   '344314': 'Marcus Tavernier',
#   '362837': 'James Hill',
#   '410998': 'Alex Scott',
#   '430350': 'Ben Gannon-Doak',
#   '295084': 'David Brooks',
#   '472122': 'Rayan',
#   '388098': 'Jérémy Doku',
#   '397821': 'Savinho',
#   '402664': 'Josko Gvardiol',
#   '93894': 'Mateo Kovacic',
#   '394749': 'Omar Marmoush',
#   '386153': 'Rayan Cherki',
#   '357073': 'Antoine Semenyo',
#   '262515': 'Gianluigi Donnarumma',
#   '343382': 'Tijjani Reijnders',
#   '315227': 'Erling Haaland',
#   '136741': 'Bernardo Silva',
#   '313171': 'Rúben Dias',
# ...
