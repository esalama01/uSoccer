# %%
import pandas as pd
df_subset = pd.read_parquet(
    '../data/spadl',
    engine='pyarrow',
    filters=[('game_id', '=', 1914251)]
)

# %%
df_subset['type_name'].value_counts()
# Out:
# pass              846
# dribble           391
# take_on            43
# tackle             37
# freekick_short     34
# foul               30
# bad_touch          29
# throw_in           28
# interception       27
# shot               26
# clearance          22
# goalkick           20
# cross              17
# keeper_save        16
# keeper_pick_up     13
# corner_crossed      6
# corner_short        2
# Name: type_name, dtype: int64
