# %%
import pandas as pd
df_subset = pd.read_parquet(
    '../data/spadl',
    engine='pyarrow',
    filters=[('game_id', '=', 1914251)]
)

# %%
df_subset.columns
# Out:
# Index(['original_event_id', 'period_id', 'time_seconds', 'team_id',
#        'player_id', 'start_x', 'end_x', 'start_y', 'end_y', 'type_id',
#        'result_id', 'bodypart_id', 'action_id', 'type_name', 'result_name',
#        'bodypart_name', 'player_name', 'team_name', 'game_id'],
#       dtype='object')
