# %%
import pandas as pd

# %%
pd.read_csv("7-Morroco-Senegal.csv")
# Out:
#                 id  event_id  minute  second  team_id     x      y  \
# 0     2.890851e+09         3       0     0.0      495  50.2   50.2
# 1     2.890851e+09         4       0     5.0      495  36.9   40.6
# 2     2.890851e+09         4       0    15.0      957  36.5  100.0
# 3     2.890851e+09         5       0    18.0      957   9.9   88.7
# 4     2.890851e+09         6       0    21.0      957   6.8   56.0
# ...            ...       ...     ...     ...      ...   ...    ...
# 1756  2.890911e+09      1003     123     5.0      957  75.4    0.0
# 1757  2.890911e+09      1038     123     9.0      495   4.2   94.7
# 1758  2.890911e+09      1039     123    10.0      495   8.8   94.2
# 1759  2.890911e+09      1004     123    10.0      957  91.1    5.8
# 1760  2.890911e+09      1040     123    25.0      495  17.4   88.0
#
#       expanded_minute                   satisfiedEventsTypes  is_touch  ...  \
# 0                   0        [91, 117, 30, 35, 38, 216, 218]      True  ...
# ...

# %%
pd.read_csv("6-Morroco-Nigeria.csv")
# Out:
#                 id  event_id  minute  second  team_id     x     y  \
# 0     2.889504e+09         3       0       0      495  50.3  50.1
# 1     2.889504e+09         4       0       4      495  31.1  37.5
# 2     2.889504e+09         4       0       9      977  28.0  86.8
# 3     2.889505e+09         7       0      18      495  93.0   0.0
# 4     2.889505e+09         8       0      22      495  77.8   7.3
# ...            ...       ...     ...     ...      ...   ...   ...
# 1859  2.889579e+09      1089     127      11      977  88.5  50.0
# 1860  2.889579e+09      1101     127      11      495   0.0   0.0
# 1861  2.889579e+09      1102     127      11      495  99.8  47.9
# 1862  2.889580e+09      1090     127      58      977   0.0   0.0
# 1863  2.889579e+09      1103     127      58      495  88.5  50.0
#
#       expanded_minute                  satisfiedEventsTypes  is_touch  ...  \
# 0                   0       [91, 117, 30, 35, 38, 215, 218]      True  ...
# ...
