# %%
import json
import pandas as pd
from socceraction.data.opta.parsers import WhoScoredParser
from socceraction.spadl.opta import convert_to_actions
from socceraction.data.opta.loader import _eventtypesdf

# %%
file_path = r"/home/esalama01/projects/uSoccer/scraper/data/La Liga/spain-laliga-2023-2024/1734624_match_data.json"

# 2. Extract the home team ID (SPADL needs this to know the playing direction)
with open(file_path, "r", encoding="utf-8") as f:
    json_data = json.load(f)

# %%
home_team_id = int(json_data["home"]["teamId"])

# %%
parser = WhoScoredParser(
    file_path,
    competition_id="La Liga",#I need to get it later out of the repo's name when automating the conversion
    season_id="2023-2024", #I need to get it later out of the repo's name when automating the conversion
    game_id=1734624, #I need to get it later out of the match's name when automating the conversion
)

# %%
df_events = pd.DataFrame.from_dict(parser.extract_events(), orient="index") #extract events returns a dictionary with all available events.
df_events = df_events.merge(_eventtypesdf, on="type_id", how="left").reset_index(drop=True) ##_eventtypesdf converts the whoscored events types to opta's --> Gets them ready for conversion

# %%
df_spadl = convert_to_actions(df_events, home_team_id=home_team_id) #Converts opta events to spadl actions.
# Out:
# /home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/socceraction/spadl/opta.py:220: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ).bfill()

# %%
df_spadl
# Out:
#       game_id original_event_id  period_id  time_seconds  team_id  player_id  \
# 0     1734624        2576688005          1           0.0       62   333048.0
# 1     1734624        2576688015          1           0.0       62    91242.0
# 2     1734624        2576688021          1           3.0       62   415345.0
# 3     1734624        2576688039          1           3.0       62   362421.0
# 4     1734624        2576688075          1           7.0       62   344200.0
# ...       ...               ...        ...           ...      ...        ...
# 1567  1734624        2576795213          2        3222.0       62   320713.0
# 1568  1734624        2576795251          2        3228.0       62   399953.0
# 1569  1734624        2576795277          2        3230.0       62   397469.0
# 1570  1734624        2576795301          2        3231.0       62   399952.0
# 1571  1734624        2576795305          2        3233.0       62   444227.0
#
#       start_x    end_x  start_y   end_y  type_id  result_id  bodypart_id  \
# 0      52.185   47.880   34.000  31.960        0          1            0
# 1      47.880   36.750   31.960  36.448        0          1            0
# 2      37.380   34.230   36.992  32.368        0          1            0
# 3      34.230   28.245   32.368  45.288        0          1            0
# 4      29.610   27.510   44.200  26.792        0          1            0
# ...       ...      ...      ...     ...      ...        ...          ...
# 1567   60.375   76.650    0.000   5.984        2          1            2
# 1568   75.285   79.800    5.984  11.560        0          1            0
# 1569   79.800   93.660   11.560   8.568        0          1            0
# 1570   94.605   92.925    8.568  28.152        0          1            0
# 1571   93.450  105.000   24.820  20.944       11          0            5
#
#       action_id
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ...         ...
# 1567       1567
# 1568       1568
# 1569       1569
# 1570       1570
# 1571       1571
#
# [1572 rows x 14 columns]
