# %%
import json
import pandas as pd
from socceraction.data.opta.parsers import WhoScoredParser
from socceraction.spadl.opta import convert_to_actions
from socceraction.data.opta.loader import _eventtypesdf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 import json
#       2 import pandas as pd
# ----> 3 from socceraction.data.opta.parsers import WhoScoredParser
#       4 from socceraction.spadl.opta import convert_to_actions
#       5 from socceraction.data.opta.loader import _eventtypesdf
#
# File ~/PycharmProjects/uSoccer/.venv/lib/python3.14/site-packages/socceraction/data/__init__.py:9
#       1 """Implements serializers for the event data of various providers."""
#       3 __all__ = [
#       4     'opta',
#       5     'statsbomb',
#       6     'wyscout',
#       7 ]
# ----> 9 from . import opta, statsbomb, wyscout
#
# File ~/PycharmProjects/uSoccer/.venv/lib/python3.14/site-packages/socceraction/data/opta/__init__.py:12
#       1 """Module for loading Opta event data."""
#       3 __all__ = [
#       4     'OptaLoader',
#       5     'OptaCompetitionSchema',
#    (...)      9     'OptaEventSchema',
#      10 ]
# ---> 12 from .loader import OptaLoader
#      13 from .schema import (
#      14     OptaCompetitionSchema,
#      15     OptaEventSchema,
#    (...)     18     OptaTeamSchema,
#      19 )
#
# File ~/PycharmProjects/uSoccer/.venv/lib/python3.14/site-packages/socceraction/data/opta/loader.py:27
#      14 from socceraction.data.base import EventDataLoader
#      16 from .parsers import (
#      17     F1JSONParser,
#      18     F7XMLParser,
#    (...)     25     WhoScoredParser,
#      26 )
# ---> 27 from .schema import (
#      28     OptaCompetitionSchema,
#      29     OptaEventSchema,
#      30     OptaGameSchema,
#      31     OptaPlayerSchema,
#      32     OptaTeamSchema,
#      33 )
#      35 _jsonparsers = {
#      36     "f1": F1JSONParser,
#      37     "f9": F9JSONParser,
#    (...)     40     "ma3": MA3JSONParser,
#      41 }
#      43 _xmlparsers = {
#      44     "f7": F7XMLParser,
#      45     "f24": F24XMLParser,
#      46 }
#
# File ~/PycharmProjects/uSoccer/.venv/lib/python3.14/site-packages/socceraction/data/opta/schema.py:8
#       5 import pandera as pa
#       6 from pandera.typing import DateTime, Object, Series
# ----> 8 from socceraction.data.schema import (
#       9     CompetitionSchema,
#      10     EventSchema,
#      11     GameSchema,
#      12     PlayerSchema,
#      13     TeamSchema,
#      14 )
#      17 class OptaCompetitionSchema(CompetitionSchema):
#      18     """Definition of a dataframe containing a list of competitions and seasons."""
#
# File ~/PycharmProjects/uSoccer/.venv/lib/python3.14/site-packages/socceraction/data/schema.py:13
#       9 import pandera as pa
#      10 from pandera.typing import DateTime, Object, Series
# ---> 13 class CompetitionSchema(pa.SchemaModel):
#      14     """Definition of a dataframe containing a list of competitions and seasons."""
#      16     season_id: Series[Object] = pa.Field()
#
# AttributeError: module 'pandera' has no attribute 'SchemaModel'

# %%
file_path = r"/home/esalama01/projects/uSoccer/scraper/data/La Liga/spain-laliga-2023-2024/1734624_match_data.json"

# 2. Extract the home team ID (SPADL needs this to know the playing direction)
with open(file_path, "r", encoding="utf-8") as f:
    json_data = json.load(f)

# %%
home_team_id = int(json_data["home"]["teamId"])

# %%
parser = WhoScoredParser(
    file_path,
    competition_id="La Liga",#I need to get it later out of the repo's name when automating the conversion
    season_id="2023-2024", #I need to get it later out of the repo's name when automating the conversion
    game_id=1734624, #I need to get it later out of the match's name when automating the conversion
)

# %%
df_events = pd.DataFrame.from_dict(parser.extract_events(), orient="index") #extract events returns a dictionary with all available events.
df_events = df_events.merge(_eventtypesdf, on="type_id", how="left").reset_index(drop=True) ##_eventtypesdf converts the whoscored events types to opta's --> Gets them ready for conversion

# %%
df_spadl = convert_to_actions(df_events, home_team_id=home_team_id) #Converts opta events to spadl actions.
# Out:
# /home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/socceraction/spadl/opta.py:220: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ).bfill()

# %%
df_spadl
# Out:
#       game_id original_event_id  period_id  time_seconds  team_id  player_id  \
# 0     1734624        2576688005          1           0.0       62   333048.0
# 1     1734624        2576688015          1           0.0       62    91242.0
# 2     1734624        2576688021          1           3.0       62   415345.0
# 3     1734624        2576688039          1           3.0       62   362421.0
# 4     1734624        2576688075          1           7.0       62   344200.0
# ...       ...               ...        ...           ...      ...        ...
# 1567  1734624        2576795213          2        3222.0       62   320713.0
# 1568  1734624        2576795251          2        3228.0       62   399953.0
# 1569  1734624        2576795277          2        3230.0       62   397469.0
# 1570  1734624        2576795301          2        3231.0       62   399952.0
# 1571  1734624        2576795305          2        3233.0       62   444227.0
#
#       start_x    end_x  start_y   end_y  type_id  result_id  bodypart_id  \
# 0      52.185   47.880   34.000  31.960        0          1            0
# 1      47.880   36.750   31.960  36.448        0          1            0
# 2      37.380   34.230   36.992  32.368        0          1            0
# 3      34.230   28.245   32.368  45.288        0          1            0
# 4      29.610   27.510   44.200  26.792        0          1            0
# ...       ...      ...      ...     ...      ...        ...          ...
# 1567   60.375   76.650    0.000   5.984        2          1            2
# 1568   75.285   79.800    5.984  11.560        0          1            0
# 1569   79.800   93.660   11.560   8.568        0          1            0
# 1570   94.605   92.925    8.568  28.152        0          1            0
# 1571   93.450  105.000   24.820  20.944       11          0            5
#
#       action_id
# 0             0
# 1             1
# 2             2
# 3             3
# 4             4
# ...         ...
# 1567       1567
# 1568       1568
# 1569       1569
# 1570       1570
# 1571       1571
#
# [1572 rows x 14 columns]

# %%
from pathlib import Path
for path in Path('../../scraper/data').iterdir():
    if path.exists():
        print(path.name)
# Out:
# Serie-a
# Epl
# World Cup
# Bundesliga
# Liga Portugal
# Netherlands Eredivisie
# Copa America
# La Liga
# Afcon
# Ucl
# Ligue-1
# Euro

# %%
import os
midox = set()
for root, dirs, files in os.walk('../../scraper/data'):
    for file in files:
        full_path = os.path.join(root, file)
    midox.add(root)
i = 0
for element in midox:
    print(element)
    i += 1
print(i)
# Out:
# ../../scraper/data/Ligue-1/france-ligue-1-2022-2023
# ../../scraper/data/Ligue-1/france-ligue-1-2024-2025
# ../../scraper/data/Ligue-1/france-ligue-1-2023-2024
# ../../scraper/data/Bundesliga/germany-bundesliga-2025-2026
# ../../scraper/data/Ligue-1
# ../../scraper/data/La Liga/spain-laliga-2024-2025
# ../../scraper/data/Euro
# ../../scraper/data/La Liga/spain-laliga-2021-2022
# ../../scraper/data/Liga Portugal/portugal-liga-2023-2024
# ../../scraper/data/Netherlands Eredivisie/netherlands-eredivisie-2022-2023
# ../../scraper/data/La Liga/spain-laliga-2022-2023
# ../../scraper/data/Liga Portugal/portugal-liga-2025-2026
# ../../scraper/data/Serie-a/italy-serie-a-2023-2024
# ../../scraper/data/Netherlands Eredivisie/netherlands-eredivisie-2024-2025
# ../../scraper/data/Epl/england-premier-league-2022-2023
# ../../scraper/data/Serie-a/italy-serie-a-2025-2026
# ../../scraper/data/Netherlands Eredivisie/netherlands-eredivisie-2021-2022
# ../../scraper/data
# ../../scraper/data/Bundesliga
# ../../scraper/data/Bundesliga/germany-bundesliga-2020-2021
# ../../scraper/data/Copa America
# ../../scraper/data/Copa America/Copa-America-2024
# ../../scraper/data/Epl
# ../../scraper/data/Ucl/Champios-League-2024-2025
# ../../scraper/data/Ligue-1/france-ligue-1-2020-2021
# ../../scraper/data/World Cup
# ../../scraper/data/Bundesliga/germany-bundesliga-2021-2022
# ../../scraper/data/Serie-a/italy-serie-a-2024-2025
# ../../scraper/data/La Liga
# ../../scraper/data/Afcon/international-africa-cup-of-nations-2025
# ../../scraper/data/Netherlands Eredivisie
# ../../scraper/data/La Liga/spain-laLiga-2025-2026
# ../../scraper/data/Epl/england-premier-league-2025-2026
# ../../scraper/data/Liga Portugal/portugal-liga-2020-2021
# ../../scraper/data/Netherlands Eredivisie/netherlands-eredivisie-2020-2021
# ../../scraper/data/Epl/england-premier-league-2023-2024
# ../../scraper/data/Afcon/international-africa-cup-of-nations-2021
# ../../scraper/data/Ucl/Champios-League-2025-2026
# ../../scraper/data/Ligue-1/france-ligue-1-2025-2026
# ../../scraper/data/Epl/england-premier-league-2024-2025
# ../../scraper/data/Liga Portugal/portugal-liga-2024-2025
# ../../scraper/data/La Liga/spain-laliga-2023-2024
# ../../scraper/data/Afcon/international-africa-cup-of-nations-2023
# ../../scraper/data/Bundesliga/germany-bundesliga-2023-2024
# ../../scraper/data/Serie-a/italy-serie-a-2022-2023
# ../../scraper/data/Afcon
# ../../scraper/data/Ucl
# ../../scraper/data/Euro/European-Championship-EURO-2020
# ../../scraper/data/Liga Portugal/portugal-liga-2021-2022
# ../../scraper/data/Serie-a/italy-serie-a-2020-2021
# ../../scraper/data/Serie-a
# ../../scraper/data/Netherlands Eredivisie/netherlands-eredivisie-2025-2026
# ../../scraper/data/Liga Portugal/portugal-liga-2022-2023
# ../../scraper/data/Bundesliga/germany-bundesliga-2024-2025
# ../../scraper/data/Serie-a/italy-serie-a-2021-2022
# ../../scraper/data/Netherlands Eredivisie/netherlands-eredivisie-2023-2024
# ../../scraper/data/Ligue-1/france-ligue-1-2021-2022
# ../../scraper/data/Euro/European-Championship-EURO-2024
# ../../scraper/data/Liga Portugal
# ../../scraper/data/La Liga/spain-laliga-2020-2021
# ../../scraper/data/Epl/england-premier-league-2021-2022
# ../../scraper/data/World Cup/Fifa-World-Cup-2022
# ../../scraper/data/Epl/england-premier-league-2020-2021
# ../../scraper/data/Bundesliga/germany-bundesliga-2022-2023
# 64

# %%
import soccerdata as sd
# Out:
# [05/11/26 13:43:15] INFO     No custom team name replacements found. You can configure these in       ]8;id=5309650;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=5309651;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_config.py#92\92]8;;\
#                              /home/esalama01/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=5309657;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=5309658;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_config.py#190\190]8;;\
#                              /home/esalama01/soccerdata/config/league_dict.json.

# %%
who = sd.WhoScored()
# Out:
#                     INFO     Saving cached data to /home/esalama01/soccerdata/data/WhoScored         ]8;id=5309665;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=5309666;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_common.py#250\250]8;;\
# [05/11/26 13:43:16] INFO     No seasons provided. Will retrieve data for the last 5 seasons.         ]8;id=5309672;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=5309673;file:///home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/soccerdata/_common.py#462\462]8;;\
#                     WARNING  /home/esalama01/projects/uSoccer/.venv/lib/python3.12/site-packages/so ]8;id=5309680;file:///usr/lib/python3.12/warnings.py\warnings.py]8;;\:]8;id=5309681;file:///usr/lib/python3.12/warnings.py#110\110]8;;\
#                              ccerdata/_common.py:419: UserWarning: The leagues have different
#                              default season codes. Using multi-year season codes.
#                                return SeasonCode.from_leagues(self.leagues)

# %%
who.available_leagues() #Those Are League ID's i must use when instanntiating a parser
# Out:
# ['ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A']

# %%
whoscored_leagues = [
    "ITA-Serie A",
    "ENG-Premier League",
    "INT-World Cup",
    "GER-Bundesliga",
    "POR-Liga Portugal",
    "NED-Eredivisie",
    "AMER-Copa America",
    "ESP-La Liga",
    "AFR-Africa Cup of Nations",
    "EUR-Champions League",
    "FRA-Ligue 1",
    "EUR-Euro"
]#Need to map those to the names of my repos.

# %%
keys = ["Serie-a",
"Epl",
"World Cup",
"Bundesliga",
"Liga Portugal",
"Netherlands Eredivisie",
"Copa America",
"La Liga,"
"Afcon",
"Ucl",
"Ligue-1",
"Euro"]
values = whoscored_leagues
map = dict(zip(keys, values))

# %%
for key, value in map.items():
    print(f"{key} : {value}")
# Out:
# Serie-a : ITA-Serie A
# Epl : ENG-Premier League
# World Cup : INT-World Cup
# Bundesliga : GER-Bundesliga
# Liga Portugal : POR-Liga Portugal
# Netherlands Eredivisie : NED-Eredivisie
# Copa America : AMER-Copa America
# La Liga,Afcon : ESP-La Liga
# Ucl : AFR-Africa Cup of Nations
# Ligue-1 : EUR-Champions League
# Euro : FRA-Ligue 1

# %%
with os.scandir('../../scraper/data') as entries:
    for entry in entries:
        if entry.is_dir():
            print(entry.path)
# Out:
# ../../scraper/data/Serie-a
# ../../scraper/data/Epl
# ../../scraper/data/World Cup
# ../../scraper/data/Bundesliga
# ../../scraper/data/Liga Portugal
# ../../scraper/data/Netherlands Eredivisie
# ../../scraper/data/Copa America
# ../../scraper/data/La Liga
# ../../scraper/data/Afcon
# ../../scraper/data/Ucl
# ../../scraper/data/Ligue-1
# ../../scraper/data/Euro

# %%
with os.scandir('../../scraper/data/Epl/england-premier-league-2024-2025') as entries:
    for entry in entries:
        if entry.is_file():
            print(entry.path.split("/"))
# Out:
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821236_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821303_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821109_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821403_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821235_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821355_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821148_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821361_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821105_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821232_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821171_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821134_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821145_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821227_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821114_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821059_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821226_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821363_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821401_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821367_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821378_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821199_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821301_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821058_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821159_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821341_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821335_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821237_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821266_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821135_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821310_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821348_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821418_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821427_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821203_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821413_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821197_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821069_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821294_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821336_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821166_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821406_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821209_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821122_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821082_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821268_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821304_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821161_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821247_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821388_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821246_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821057_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821409_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821257_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821352_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821206_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821201_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821052_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821256_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821195_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821188_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821393_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821244_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821139_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821271_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821342_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821366_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821124_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821399_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821428_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821377_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821157_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821160_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821181_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821343_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821113_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821174_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821253_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821254_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821180_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821136_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821415_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821396_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821095_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821156_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821142_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821290_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821072_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821351_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821193_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821234_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821416_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821407_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821141_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821205_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821321_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821238_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821369_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821423_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821298_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821154_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821061_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821170_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821389_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821322_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821211_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821255_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821357_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821245_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821397_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821133_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821107_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821320_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821285_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821274_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821190_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821241_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821128_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821376_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821106_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821325_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821306_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821119_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821224_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821426_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821296_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821398_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821167_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821213_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821065_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821365_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821169_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821090_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821117_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821273_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821239_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821200_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821220_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821272_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821359_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821374_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821100_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821284_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821101_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821349_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821198_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821331_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821202_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821280_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821131_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821248_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821210_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821083_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821063_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821075_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821308_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821372_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821356_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821333_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821287_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821129_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821233_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821221_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821260_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821076_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821371_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821327_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821387_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821334_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821078_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821309_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821102_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821089_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821323_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821146_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821077_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821347_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821345_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821405_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821103_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821130_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821165_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821329_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821216_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821054_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821278_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821218_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821394_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821295_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821066_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821155_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821404_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821259_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821354_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821316_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821332_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821164_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821087_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821049_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821258_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821074_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821414_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821143_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821092_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821279_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821192_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821373_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821391_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821189_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821420_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821358_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821149_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821126_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821212_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821222_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821115_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821111_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821062_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821118_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821064_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821261_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821125_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821293_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821217_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821313_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821346_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821084_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821097_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821073_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821110_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821395_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821269_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821252_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821267_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821368_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821132_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821262_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821392_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821219_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821152_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821185_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821324_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821093_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821362_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821080_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821162_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821138_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821417_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821182_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821375_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821184_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821127_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821344_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821307_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821289_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821288_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821094_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821364_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821379_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821383_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821079_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821249_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821204_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821137_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821121_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821085_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821302_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821088_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821055_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821051_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821120_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821339_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821228_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821312_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821173_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821070_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821179_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821186_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821230_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821380_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821317_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821251_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821187_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821408_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821108_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821172_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821381_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821318_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821196_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821286_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821151_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821053_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821299_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821060_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821123_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821410_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821250_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821178_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821411_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821144_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821104_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821283_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821385_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821225_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821265_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821319_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821292_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821207_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821158_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821425_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821176_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821099_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821337_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821214_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821071_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821275_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821386_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821402_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821231_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821112_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821276_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821315_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821191_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821240_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821360_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821419_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821291_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821297_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821098_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821215_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821264_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821140_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821421_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821242_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821096_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821263_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821153_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821223_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821338_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821067_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821175_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821194_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821340_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821183_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821412_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821330_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821050_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821384_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821116_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821229_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821314_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821300_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821086_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821400_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821311_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821091_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821177_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821350_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821243_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821370_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821068_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821382_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821353_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821328_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821281_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821424_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821277_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821270_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821390_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821056_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821326_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821081_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821422_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821147_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821305_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821168_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821163_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821282_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821150_match_data.json']
# ['..', '..', 'scraper', 'data', 'Epl', 'england-premier-league-2024-2025', '1821208_match_data.json']

# %%
#../../scraper/data/Epl/england-premier-league-2024-2025/1821236_match_data.json
